# %%
# !nvidia-smi
# Out:
# Thu Mar  9 21:38:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 472.50       Driver Version: 472.50       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# |  0%   50C    P8    15W / 320W |   8477MiB / 10240MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      9540      C   ...User\anaconda3\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Settings

# %%
# 필요 모델 호출
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import math
import time
import random
import tensorflow as tf

# %%
def seed_everything(seed: int = 2022):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
class config:
    seed = 2022

# %%
seed_everything(config.seed)
# seed = 2022
# tf.random.set_seed(seed)

# %% [markdown]
# # Load Dataset

# %%
# 이미지 로드
imglist = os.listdir('/Users/User/303/COVID-19_Radiography_Dataset/COVID/images/')
def load_image(path):
    image_list = np.zeros((len(imglist), 128, 128))
    for i in range(len(imglist)):
        img = Image.open('/Users/User/303/COVID-19_Radiography_Dataset/COVID/images/'+str(imglist[i])).convert('L')
        image_list[i] = img
    return image_list

# %%
posi = load_image('/Users/User/303/COVID-19_Radiography_Dataset/COID/images/*.png')
posi = posi.astype('float32')/255.
print(posi.shape)
# Out:
# (3616, 128, 128)

# %% [markdown]
# # Train Validation Test Split

# %%
from sklearn.model_selection import train_test_split

X_trainval, x_test = train_test_split(posi, test_size=0.2, random_state=43)
x_train, x_val = train_test_split(X_trainval, train_size=0.75, random_state=43)

# %%
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (2169, 128, 128)
# (723, 128, 128)
# (724, 128, 128)

# %%
# def train_test_split(img):
#     rnd = np.random.RandomState(seed=51)
#     perm = rnd.permutation(len(img))
#     train_idx = perm[:int(0.8 * len(img))]
#     test_idx = perm[int(0.8 * len(img)):]
#     return img[train_idx], img[test_idx]

# x_train, x_test = train_test_split(posi)
# print(x_train.shape, x_test.shape)

# %% [markdown]
# # Noise

# %%
def noisy(noise_typ,image):
    #Gaussian Noisy
    if noise_typ == "gauss":
        
        noisy = image + 0.1 *  np.random.normal(loc=0,scale=1.,size=image.shape)
        return noisy
    #Salt & Pepper Noisy
    elif noise_typ == "s&p":
        row,col,ch = image.shape
        s_vs_p = 0.5
        amount = 0.05
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
              for i in image.shape]
        out[tuple(coords)] = 1
        # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[tuple(coords)] = 0
        return out

    # Speckle Noisy
    elif noise_typ =="speckle":
        noisy = np.random.normal(loc=0,scale=1.,size=image.shape)
        noisy = image+ image * 0.1 *noisy
        return noisy
    # Poisson Noisy
    elif noise_typ == "poisson":
        
        noisy = image + 0.1 *  np.random.poisson(lam=1.0,size=image.shape)
        return noisy

# %%
def MAE(img1, img2):
    D = np.array(img1 - img2, dtype=np.float64)
    D[:, :] = np.abs(D[:, :])
    MAE = D.sum()/img1.size
    return MAE

def PSNR(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 1.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
from skimage.restoration import denoise_nl_means, denoise_bilateral
from scipy.signal import medfilt2d
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance
from skimage.util import random_noise

def Meanfilter(noisy_test_data):
    meanfilter = []
    for i in range(len(noisy_test_data)):
         meanfilter.append(cv2.blur(noisy_test_data[i],(3,3)))
    meanfilter = np.array(meanfilter)
    return meanfilter
    
def Medianfilter(noisy_test_data):
    medianfilter = []
    for i in range(len(noisy_test_data)):
        medianfilter.append(medfilt2d(noisy_test_data[i],(3,3)))
    medianfilter = np.array(medianfilter)
    return medianfilter


def lee_filter(img):
    lee = []
    for i in range(len(img)):
        img_mean = uniform_filter(img[i])
        img_sqr_mean = uniform_filter(img[i]**2)
        img_variance = img_sqr_mean - img_mean**2
        
        overall_variance = variance(img[i])
        
        img_weights = (img_variance**2) / ((img_variance**2) + (overall_variance**2))
        img_output = img_mean + img_weights * (img[i] - img_mean)
        
        lee.append(img_output)
    lee = np.array(lee)
    return lee

# %%
# Add Noisy
x_train_sp_noisy = noisy("gauss",x_train)
x_val_sp_noisy = noisy("gauss",x_val)

x_test_sp_noisy = noisy("gauss",x_test)

x_train_sp_noisy=x_train_sp_noisy.clip(0,1)
x_val_sp_noisy=x_val_sp_noisy.clip(0,1)

x_test_sp_noisy=x_test_sp_noisy.clip(0,1)
x_train_sp_noisy[0]
# Out:
# array([[0.00035899, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.12233069, 0.        , 0.        , ..., 0.03216973, 0.03005238,
#         0.        ],
#        [0.05313872, 0.        , 0.0420452 , ..., 0.054452  , 0.0060859 ,
#         0.23303641],
#        ...,
#        [0.        , 0.        , 0.01349784, ..., 0.        , 0.05622983,
#         0.01253472],
#        [0.07566415, 0.09126364, 0.2481241 , ..., 0.        , 0.02716334,
#         0.        ],
#        [0.        , 0.07229008, 0.        , ..., 0.20348187, 0.        ,
#         0.        ]])

# %%
# Original Image
ax = plt.subplot()
plt.imshow(x_test[21], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Original Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# Salt & Pepper Noisy Image
ax = plt.subplot()
plt.imshow(x_test_sp_noisy[21], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(poisson Noisy Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# MeanFilter Image
start = time.time()
mean_x_test_sp_noisy = Meanfilter(x_test_sp_noisy)
end = time.time()
Meantime= end - start
print("CPU 시간 : "+str(Meantime))

ax = plt.subplot()
plt.imshow(mean_x_test_sp_noisy[21], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(poisson Noisy Meanfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()
# Out:
# CPU 시간 : 0.062378644943237305

# %%
# MedianFilter Image
start = time.time()
median_x_test_sp_noisy = Medianfilter(x_test_sp_noisy)
end = time.time()
Mediantime= end - start
print("CPU 시간 : "+str(Mediantime))

ax = plt.subplot()
plt.imshow(median_x_test_sp_noisy[21], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Out:
# CPU 시간 : 0.9215559959411621

# %%
#Convolution Neural Networks Filter Image
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, UpSampling2D
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from keras import optimizers
from keras.models import Model

# %%
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D ,LeakyReLU,ReLU,Concatenate
from keras import optimizers
from keras.models import Model

# %%
x_train_sp_noisy= tf.convert_to_tensor(x_train_sp_noisy)
x_val_sp_noisy= tf.convert_to_tensor(x_val_sp_noisy)
x_test_sp_noisy= tf.convert_to_tensor(x_test_sp_noisy)

x_train_sp_noisy.dtype

x_train_sp_noisy[0]
# Out:
# <tf.Tensor: shape=(128, 128), dtype=float64, numpy=
# array([[0.03529412, 0.12352941, 0.02352941, ..., 0.21176471, 0.11176471,
#         0.02352941],
#        [0.13137255, 0.11960784, 0.31960784, ..., 0.11176471, 0.01176471,
#         0.02352941],
#        [0.22745098, 0.31568628, 0.11568628, ..., 0.00784314, 0.10784314,
#         0.22352941],
#        ...,
#        [0.01568628, 0.2       , 0.00392157, ..., 0.10392157, 0.1       ,
#         0.31568628],
#        [0.01568628, 0.2       , 0.20392157, ..., 0.10392157, 0.2       ,
#         0.01568628],
#        [0.11568628, 0.4       , 0.10392157, ..., 0.10392157, 0.1       ,
#         0.01568628]])>

# %%
"""
SPDX-License-Identifier: MIT
Copyright © 2018 - 2022 Markus Völk
Code was taken from https://github.com/mvoelk/keras_layers
"""
#https://github.com/mvoelk/keras_layers
import numpy as np
import tensorflow as tf

from keras import backend as K
from keras.layers import Layer, Lambda
from keras.layers import InputSpec
from keras import initializers, regularizers, constraints, activations
from keras.utils import conv_utils

class Conv2DBaseLayer(Layer):
    """Basic Conv2D class from which other layers inherit.
    """
    def __init__(self,
                 kernel_size,
                 strides=(1, 1),
                 padding='same',
                 #data_format=None,
                 dilation_rate=(1, 1),
                 activation=None,
                 use_bias=True,
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=None,
                 kernel_constraint=None,
                 bias_initializer='zeros',
                 bias_regularizer=None,
                 bias_constraint=None,
                 activity_regularizer=None,
                 **kwargs):

        super(Conv2DBaseLayer, self).__init__(
            activity_regularizer=regularizers.get(activity_regularizer), **kwargs)

        self.rank = rank = 2
        self.kernel_size = conv_utils.normalize_tuple(kernel_size, rank, 'kernel_size')
        self.strides = conv_utils.normalize_tuple(strides, rank, 'strides')
        self.padding = conv_utils.normalize_padding(padding)
        self.dilation_rate = conv_utils.normalize_tuple(dilation_rate, rank, 'dilation_rate')
        self.activation = activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = initializers.get(kernel_initializer)
        self.kernel_regularizer = regularizers.get(kernel_regularizer)
        self.kernel_constraint = constraints.get(kernel_constraint)
        self.bias_initializer = initializers.get(bias_initializer)
        self.bias_regularizer = regularizers.get(bias_regularizer)
        self.bias_constraint = constraints.get(bias_constraint)

    def get_config(self):
        config = super(Conv2DBaseLayer, self).get_config()
        config.update({
            'kernel_size': self.kernel_size,
            'strides': self.strides,
            'padding': self.padding,
            'dilation_rate': self.dilation_rate,
            'activation': activations.serialize(self.activation),
            'use_bias': self.use_bias,
            'kernel_initializer': initializers.serialize(self.kernel_initializer),
            'kernel_regularizer': regularizers.serialize(self.kernel_regularizer),
            'kernel_constraint': constraints.serialize(self.kernel_constraint),
            'bias_initializer': initializers.serialize(self.bias_initializer),
            'bias_regularizer': regularizers.serialize(self.bias_regularizer),
            'bias_constraint': constraints.serialize(self.bias_constraint),
            'activity_regularizer': regularizers.serialize(self.activity_regularizer),
        })
        return config

class DeformableConv2D(Conv2DBaseLayer):
    """2D Deformable Convolution layer that learns the spatial offsets where 
    the input elements of the convolution are sampled.
    
    The layer is basically a updated version of An Jiaoyang's code.
    
    # Notes
        - The layer does not use a native CUDA kernel which would have better 
          performance https://github.com/tensorflow/addons/issues/179
    
    # References
        [Deformable Convolutional Networks](https://arxiv.org/abs/1703.06211)
    
    # related code
        https://github.com/DHZS/tf-deformable-conv-layer (An Jiaoyang, 2018-10-11)
    """
    
    def __init__(self, filters, kernel_size, num_deformable_group=None, **kwargs):
        """`kernel_size`, `strides` and `dilation_rate` must have the same value in both axis.
        
        :param num_deformable_group: split output channels into groups, offset shared in each group. If
        this parameter is None, then set num_deformable_group=filters.
        """
        super(DeformableConv2D, self).__init__(kernel_size, **kwargs)
        
        if not self.kernel_size[0] == self.kernel_size[1]:
            raise ValueError('Requires square kernel')
        if not self.strides[0] == self.strides[1]:
            raise ValueError('Requires equal stride')
        if not self.dilation_rate[0] == self.dilation_rate[1]:
            raise ValueError('Requires equal dilation')
        
        self.filters = filters
        if num_deformable_group is None:
            num_deformable_group = filters
        if filters % num_deformable_group != 0:
            raise ValueError('"filters" mod "num_deformable_group" must be zero')
        self.num_deformable_group = num_deformable_group
        
        self.kernel = None
        self.bias = None
        self.offset_layer_kernel = None
        self.offset_layer_bias = None
    
    def build(self, input_shape):
        
        input_dim = input_shape[-1]
        # kernel_shape = self.kernel_size + (input_dim, self.filters)
        # we want to use depth-wise conv
        kernel_shape = self.kernel_size + (self.filters * input_dim, 1)
        self.kernel = self.add_weight(name='kernel',
                        shape=kernel_shape,
                        initializer=self.kernel_initializer,
                        regularizer=self.kernel_regularizer,
                        constraint=self.kernel_constraint,
                        trainable=True,
                        dtype=self.dtype)
        if self.use_bias:
            self.bias = self.add_weight(name='bias',
                            shape=(self.filters,),
                            initializer=self.bias_initializer,
                            regularizer=self.bias_regularizer,
                            constraint=self.bias_constraint,
                            trainable=True,
                            dtype=self.dtype)
        
        # create offset conv layer
        offset_num = self.kernel_size[0] * self.kernel_size[1] * self.num_deformable_group
        self.offset_layer_kernel = self.add_weight(name='offset_layer_kernel',
                        shape=self.kernel_size + (input_dim, offset_num * 2),  # 2 means x and y axis
                        initializer=tf.zeros_initializer(),
                        regularizer=self.kernel_regularizer,
                        trainable=True,
                        dtype=self.dtype)
        self.offset_layer_bias = self.add_weight(name='offset_layer_bias',
                        shape=(offset_num * 2,),
                        initializer=tf.zeros_initializer(),
                        # initializer=tf.random_uniform_initializer(-5, 5),
                        regularizer=self.bias_regularizer,
                        trainable=True,
                        dtype=self.dtype)
        self.built = True
    
    def call(self, inputs, training=None, **kwargs):
        # get offset, shape [batch_size, out_h, out_w, filter_h, * filter_w * channel_out * 2]
        offset = tf.nn.conv2d(inputs,
                              filters=self.offset_layer_kernel,
                              strides=[1, *self.strides, 1],
                              padding=self.padding.upper(),
                              dilations=[1, *self.dilation_rate, 1])
        offset += self.offset_layer_bias
        
        # add padding if needed
        inputs = self._pad_input(inputs)
        
        # some length
        batch_size = tf.shape(inputs)[0]
        channel_in = int(inputs.shape[-1])
        
        in_h, in_w = [int(i) for i in inputs.shape[1: 3]]  # input feature map size
        out_h, out_w = [int(i) for i in offset.shape[1: 3]]  # output feature map size
        filter_h, filter_w = self.kernel_size
        
        # get x, y axis offset
        offset = tf.reshape(offset, [batch_size, out_h, out_w, -1, 2])
        y_off, x_off = offset[:, :, :, :, 0], offset[:, :, :, :, 1]
        
        # input feature map gird coordinates
        y, x = self._get_conv_indices([in_h, in_w])
        y, x = [tf.expand_dims(i, axis=-1) for i in [y, x]]
        y, x = [tf.tile(i, [batch_size, 1, 1, 1, self.num_deformable_group]) for i in [y, x]]
        y, x = [tf.reshape(i, [batch_size, *i.shape[1: 3], -1]) for i in [y, x]]
        y, x = [tf.cast(i, 'float32') for i in [y, x]]
        
        # add offset
        y, x = y + y_off, x + x_off
        y = tf.clip_by_value(y, 0, in_h - 1)
        x = tf.clip_by_value(x, 0, in_w - 1)
        
        # get four coordinates of points around (x, y)
        y0, x0 = [tf.cast(tf.floor(i), 'int32') for i in [y, x]]
        y1, x1 = y0 + 1, x0 + 1
        # clip
        y0, y1 = [tf.clip_by_value(i, 0, in_h - 1) for i in [y0, y1]]
        x0, x1 = [tf.clip_by_value(i, 0, in_w - 1) for i in [x0, x1]]
        
        # get pixel values
        indices = [[y0, x0], [y0, x1], [y1, x0], [y1, x1]]
        p0, p1, p2, p3 = [DeformableConv2D._get_pixel_values_at_point(inputs, i) for i in indices]
        
        # cast to float
        x0, x1, y0, y1 = [tf.cast(i, 'float32') for i in [x0, x1, y0, y1]]
        # weights
        w0 = (y1 - y) * (x1 - x)
        w1 = (y1 - y) * (x - x0)
        w2 = (y - y0) * (x1 - x)
        w3 = (y - y0) * (x - x0)
        # expand dim for broadcast
        w0, w1, w2, w3 = [tf.expand_dims(i, axis=-1) for i in [w0, w1, w2, w3]]
        # bilinear interpolation
        pixels = tf.add_n([w0 * p0, w1 * p1, w2 * p2, w3 * p3])
        
        # reshape the "big" feature map
        pixels = tf.reshape(pixels, [batch_size, out_h, out_w, filter_h, filter_w, self.num_deformable_group, channel_in])
        pixels = tf.transpose(pixels, [0, 1, 3, 2, 4, 5, 6])
        pixels = tf.reshape(pixels, [batch_size, out_h * filter_h, out_w * filter_w, self.num_deformable_group, channel_in])
        
        # copy channels to same group
        feat_in_group = self.filters // self.num_deformable_group
        pixels = tf.tile(pixels, [1, 1, 1, 1, feat_in_group])
        pixels = tf.reshape(pixels, [batch_size, out_h * filter_h, out_w * filter_w, -1])
        
        # depth-wise conv
        out = tf.nn.depthwise_conv2d(pixels, self.kernel, [1, filter_h, filter_w, 1], 'VALID')
        # add the output feature maps in the same group
        out = tf.reshape(out, [batch_size, out_h, out_w, self.filters, channel_in])
        out = tf.reduce_sum(out, axis=-1)
        if self.use_bias:
            out += self.bias
        return self.activation(out)
    
    def _pad_input(self, inputs):
        """Check if input feature map needs padding, because we don't use the standard Conv() function.
        
        :param inputs:
        :return: padded input feature map
        """
        # When padding is 'same', we should pad the feature map.
        # if padding == 'same', output size should be `ceil(input / stride)`
        if self.padding == 'same':
            in_shape = inputs.shape.as_list()[1:3]
            padding_list = []
            for i in range(2):
                filter_size = self.kernel_size[i]
                dilation = self.dilation_rate[i]
                dilated_filter_size = filter_size + (filter_size - 1) * (dilation - 1)
                same_output = (in_shape[i] + self.strides[i] - 1) // self.strides[i]
                valid_output = (in_shape[i] - dilated_filter_size + self.strides[i]) // self.strides[i]
                if same_output == valid_output:
                    padding_list += [0, 0]
                else:
                    p = dilated_filter_size - 1
                    p_0 = p // 2
                    padding_list += [p_0, p - p_0]
            if sum(padding_list) != 0:
                padding = [[0, 0],
                           [padding_list[0], padding_list[1]],  # top, bottom padding
                           [padding_list[2], padding_list[3]],  # left, right padding
                           [0, 0]]
                inputs = tf.pad(inputs, padding)
        return inputs
    
    def _get_conv_indices(self, feature_map_size):
        """the x, y coordinates in the window when a filter sliding on the feature map

        :param feature_map_size:
        :return: y, x with shape [1, out_h, out_w, filter_h * filter_w]
        """
        feat_h, feat_w = [int(i) for i in feature_map_size[0: 2]]

        x, y = tf.meshgrid(tf.range(feat_w), tf.range(feat_h))
        x, y = [tf.reshape(i, [1, *i.get_shape(), 1]) for i in [x, y]]  # shape [1, h, w, 1]
        x, y = [tf.image.extract_patches(i,
                                         [1, *self.kernel_size, 1],
                                         [1, *self.strides, 1],
                                         [1, *self.dilation_rate, 1],
                                         'VALID')
                for i in [x, y]]  # shape [1, out_h, out_w, filter_h * filter_w]
        return y, x

    @staticmethod
    def _get_pixel_values_at_point(inputs, indices):
        """get pixel values

        :param inputs:
        :param indices: shape [batch_size, H, W, I], I = filter_h * filter_w * channel_out
        :return:
        """
        y, x = indices
        batch, h, w, n = y.shape.as_list()[0: 4]
        
        y_shape = tf.shape(y)
        batch, n = y_shape[0], y_shape[3]
        
        batch_idx = tf.reshape(tf.range(0, batch), (batch, 1, 1, 1))
        b = tf.tile(batch_idx, (1, h, w, n))
        pixel_idx = tf.stack([b, y, x], axis=-1)
        return tf.gather_nd(inputs, pixel_idx)

# %%
epochs = 100
inChannel = 1
x, y = 128, 128
batch_size=9

# %%
act=ReLU()

# %%
#Convolution Neural Networks Filter Image
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, UpSampling2D
# Convolution Auto Encoder Filter Image
from keras.layers import Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from keras import optimizers
from keras.models import Model

# %%
# Encoder
input_img = Input(shape=(x,y,inChannel))
conv1 = DeformableConv2D(16, (3,3),num_deformable_group=4)(input_img)
conv1 = ReLU()(conv1)
pool1 = MaxPooling2D(pool_size=(2,2))(conv1) 
conv1 = DeformableConv2D(32, (3,3),num_deformable_group=4)(pool1)
conv1 = ReLU()(conv1)
pool2 = MaxPooling2D(pool_size=(2,2))(conv1)
encoded = DeformableConv2D(64, (3,3),num_deformable_group=4)(pool2)
encoded = ReLU()(encoded)

# Decoder 
conv4 = Conv2D(64,(3, 3), padding='same',activation=act)(encoded)
up1 = UpSampling2D((2,2),name='up1')(conv4)
conv5 = Conv2D(32,(3, 3), padding='same',activation=act)(up1)
up2 = UpSampling2D((2,2),name='up2')(conv5)
decoded = Conv2D(1, (3,3), activation='sigmoid', padding='same',name='decoder3_cov')(up2)

# %%
def PSNR1(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

# %%
def SSIM1(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# %%
# CAEFilter Image
autoencoder_sp = Model(input_img, decoded)
autoencoder_sp.compile(loss='mean_squared_error',optimizer=optimizers.Adam(),metrics=[PSNR1,SSIM1],run_eagerly=True)
autoencoder_sp.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  deformable_conv2d_3 (Deform  (None, 128, 128, 16)     880
#  ableConv2D)
#
#  re_lu_5 (ReLU)              (None, 128, 128, 16)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  deformable_conv2d_4 (Deform  (None, 64, 64, 32)       15080
#  ableConv2D)
#
#  re_lu_6 (ReLU)              (None, 64, 64, 32)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  deformable_conv2d_5 (Deform  (None, 32, 32, 64)       39304
#  ableConv2D)
#
#  re_lu_7 (ReLU)              (None, 32, 32, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        36928
#
#  up1 (UpSampling2D)          (None, 64, 64, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        18464
#
#  up2 (UpSampling2D)          (None, 128, 128, 32)      0
#
#  decoder3_cov (Conv2D)       (None, 128, 128, 1)       289
#
# =================================================================
# Total params: 110,945
# Trainable params: 110,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau,LearningRateScheduler,Callback

#경로 바꿔주기
filename = './checkpoint/De_CAE_poisson_42_추가.ckpt'
checkpoint = ModelCheckpoint(filename,             
                             monitor= 'val_loss',
                             save_weights_only=True,
                             verbose=1,           
                             save_best_only=True,  
                             mode='min'         
                            )

# %%
x_train_cae = tf.convert_to_tensor(x_train)
x_train_cae = tf.reshape(x_train_cae,(2169, 128, 128,1))

x_val_cae = tf.convert_to_tensor(x_val)
x_val_cae = tf.reshape(x_val_cae,(723, 128, 128,1))


x_test_cae = tf.convert_to_tensor(x_test)
x_test_cae = tf.reshape(x_test_cae,(724, 128, 128,1))

x_train_cae_sp_noisy = tf.reshape(x_train_sp_noisy,[-1, 128, 128, 1])
x_val_cae_sp_noisy = tf.reshape(x_val_sp_noisy,[-1, 128, 128, 1])
x_test_cae_sp_noisy = tf.reshape(x_test_sp_noisy,[-1, 128, 128,1])

# %%
autoencodersp_train = autoencoder_sp.fit(x_train_cae_sp_noisy, x_train_cae, 
                                        batch_size=batch_size, 
                                        epochs=epochs, 
                                        verbose=2,
                                        validation_data=(x_val_cae_sp_noisy, x_val_cae)
                                        ,callbacks=[checkpoint])
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.00165, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 102s - loss: 0.0084 - PSNR1: 24.2809 - SSIM1: 0.7550 - val_loss: 0.0017 - val_PSNR1: 28.3359 - val_SSIM1: 0.8216 - 102s/epoch - 424ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.00165 to 0.00154, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 0.0015 - PSNR1: 28.7411 - SSIM1: 0.8281 - val_loss: 0.0015 - val_PSNR1: 28.4921 - val_SSIM1: 0.8343 - 101s/epoch - 420ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.00154 to 0.00119, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 0.0013 - PSNR1: 29.2786 - SSIM1: 0.8386 - val_loss: 0.0012 - val_PSNR1: 29.6971 - val_SSIM1: 0.8430 - 101s/epoch - 419ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.00119 to 0.00112, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 0.0012 - PSNR1: 29.7241 - SSIM1: 0.8450 - val_loss: 0.0011 - val_PSNR1: 29.9277 - val_SSIM1: 0.8483 - 101s/epoch - 419ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.00112
# 241/241 - 101s - loss: 0.0011 - PSNR1: 29.8474 - SSIM1: 0.8493 - val_loss: 0.0012 - val_PSNR1: 29.4854 - val_SSIM1: 0.8532 - 101s/epoch - 419ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.00112 to 0.00095, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 0.0011 - PSNR1: 30.1035 - SSIM1: 0.8547 - val_loss: 9.5245e-04 - val_PSNR1: 30.6254 - val_SSIM1: 0.8579 - 101s/epoch - 420ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.00095 to 0.00090, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 9.5148e-04 - PSNR1: 30.5741 - SSIM1: 0.8603 - val_loss: 9.0098e-04 - val_PSNR1: 30.8260 - val_SSIM1: 0.8627 - 101s/epoch - 420ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.00090
# 241/241 - 101s - loss: 8.9005e-04 - PSNR1: 30.8552 - SSIM1: 0.8642 - val_loss: 9.0698e-04 - val_PSNR1: 30.7201 - val_SSIM1: 0.8668 - 101s/epoch - 419ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.00090 to 0.00082, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 8.9387e-04 - PSNR1: 30.8412 - SSIM1: 0.8670 - val_loss: 8.2394e-04 - val_PSNR1: 31.2006 - val_SSIM1: 0.8693 - 101s/epoch - 420ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.00082
# 241/241 - 101s - loss: 8.4608e-04 - PSNR1: 31.0667 - SSIM1: 0.8698 - val_loss: 9.1485e-04 - val_PSNR1: 30.6701 - val_SSIM1: 0.8716 - 101s/epoch - 419ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.00082 to 0.00082, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 8.1067e-04 - PSNR1: 31.2379 - SSIM1: 0.8723 - val_loss: 8.1779e-04 - val_PSNR1: 31.1672 - val_SSIM1: 0.8738 - 101s/epoch - 419ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.00082 to 0.00082, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 7.9911e-04 - PSNR1: 31.3001 - SSIM1: 0.8744 - val_loss: 8.1591e-04 - val_PSNR1: 31.1957 - val_SSIM1: 0.8760 - 101s/epoch - 419ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.00082 to 0.00073, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 7.8803e-04 - PSNR1: 31.3752 - SSIM1: 0.8764 - val_loss: 7.2740e-04 - val_PSNR1: 31.7189 - val_SSIM1: 0.8782 - 101s/epoch - 420ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.00073
# 241/241 - 101s - loss: 7.6781e-04 - PSNR1: 31.4762 - SSIM1: 0.8782 - val_loss: 8.1280e-04 - val_PSNR1: 31.1449 - val_SSIM1: 0.8807 - 101s/epoch - 419ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.00073
# 241/241 - 101s - loss: 7.4351e-04 - PSNR1: 31.6154 - SSIM1: 0.8803 - val_loss: 7.4862e-04 - val_PSNR1: 31.5730 - val_SSIM1: 0.8821 - 101s/epoch - 418ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.00073 to 0.00069, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 7.3702e-04 - PSNR1: 31.6525 - SSIM1: 0.8820 - val_loss: 6.8984e-04 - val_PSNR1: 31.9550 - val_SSIM1: 0.8827 - 101s/epoch - 419ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.00069
# 241/241 - 101s - loss: 7.2397e-04 - PSNR1: 31.7317 - SSIM1: 0.8837 - val_loss: 9.2214e-04 - val_PSNR1: 30.5779 - val_SSIM1: 0.8823 - 101s/epoch - 419ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.00069
# 241/241 - 101s - loss: 7.1479e-04 - PSNR1: 31.7930 - SSIM1: 0.8855 - val_loss: 7.2103e-04 - val_PSNR1: 31.7426 - val_SSIM1: 0.8874 - 101s/epoch - 419ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.00069 to 0.00069, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 6.8976e-04 - PSNR1: 31.9443 - SSIM1: 0.8873 - val_loss: 6.8748e-04 - val_PSNR1: 31.9311 - val_SSIM1: 0.8872 - 101s/epoch - 419ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.00069 to 0.00069, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 6.8977e-04 - PSNR1: 31.9475 - SSIM1: 0.8886 - val_loss: 6.8542e-04 - val_PSNR1: 31.9286 - val_SSIM1: 0.8901 - 101s/epoch - 420ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.00069 to 0.00065, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 6.6986e-04 - PSNR1: 32.0875 - SSIM1: 0.8906 - val_loss: 6.4828e-04 - val_PSNR1: 32.2125 - val_SSIM1: 0.8913 - 101s/epoch - 420ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.00065 to 0.00063, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 6.5771e-04 - PSNR1: 32.1640 - SSIM1: 0.8921 - val_loss: 6.2759e-04 - val_PSNR1: 32.3604 - val_SSIM1: 0.8936 - 101s/epoch - 419ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.00063 to 0.00062, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 6.5482e-04 - PSNR1: 32.1775 - SSIM1: 0.8934 - val_loss: 6.2017e-04 - val_PSNR1: 32.4260 - val_SSIM1: 0.8948 - 101s/epoch - 419ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00062
# 241/241 - 101s - loss: 6.5784e-04 - PSNR1: 32.1655 - SSIM1: 0.8945 - val_loss: 6.6359e-04 - val_PSNR1: 32.0708 - val_SSIM1: 0.8938 - 101s/epoch - 420ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.00062
# 241/241 - 101s - loss: 6.1961e-04 - PSNR1: 32.4361 - SSIM1: 0.8963 - val_loss: 6.2428e-04 - val_PSNR1: 32.3872 - val_SSIM1: 0.8981 - 101s/epoch - 418ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.00062 to 0.00061, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 6.1814e-04 - PSNR1: 32.4399 - SSIM1: 0.8978 - val_loss: 6.0854e-04 - val_PSNR1: 32.4964 - val_SSIM1: 0.8995 - 101s/epoch - 419ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.00061 to 0.00058, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 6.0583e-04 - PSNR1: 32.5324 - SSIM1: 0.8992 - val_loss: 5.7730e-04 - val_PSNR1: 32.7515 - val_SSIM1: 0.8997 - 101s/epoch - 420ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00058
# 241/241 - 101s - loss: 5.9919e-04 - PSNR1: 32.5772 - SSIM1: 0.9004 - val_loss: 5.7826e-04 - val_PSNR1: 32.7501 - val_SSIM1: 0.9024 - 101s/epoch - 419ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00058
# 241/241 - 101s - loss: 6.1497e-04 - PSNR1: 32.4609 - SSIM1: 0.9012 - val_loss: 6.0154e-04 - val_PSNR1: 32.5588 - val_SSIM1: 0.9023 - 101s/epoch - 419ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00058
# 241/241 - 101s - loss: 5.8260e-04 - PSNR1: 32.7093 - SSIM1: 0.9026 - val_loss: 6.0402e-04 - val_PSNR1: 32.4923 - val_SSIM1: 0.9036 - 101s/epoch - 419ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00058
# 241/241 - 103s - loss: 5.7355e-04 - PSNR1: 32.7823 - SSIM1: 0.9037 - val_loss: 6.8873e-04 - val_PSNR1: 31.8738 - val_SSIM1: 0.9034 - 103s/epoch - 427ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.00058 to 0.00055, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.8742e-04 - PSNR1: 32.6611 - SSIM1: 0.9041 - val_loss: 5.4968e-04 - val_PSNR1: 32.9697 - val_SSIM1: 0.9056 - 101s/epoch - 420ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.00055 to 0.00054, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.8187e-04 - PSNR1: 32.7304 - SSIM1: 0.9047 - val_loss: 5.4207e-04 - val_PSNR1: 33.0342 - val_SSIM1: 0.9072 - 101s/epoch - 420ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00054
# 241/241 - 101s - loss: 5.6993e-04 - PSNR1: 32.8175 - SSIM1: 0.9060 - val_loss: 5.8551e-04 - val_PSNR1: 32.6601 - val_SSIM1: 0.9061 - 101s/epoch - 419ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00054
# 241/241 - 101s - loss: 5.7086e-04 - PSNR1: 32.8087 - SSIM1: 0.9061 - val_loss: 5.4269e-04 - val_PSNR1: 33.0250 - val_SSIM1: 0.9073 - 101s/epoch - 419ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.00054 to 0.00053, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.4944e-04 - PSNR1: 32.9686 - SSIM1: 0.9075 - val_loss: 5.3113e-04 - val_PSNR1: 33.1248 - val_SSIM1: 0.9085 - 101s/epoch - 421ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.00053 to 0.00052, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.3795e-04 - PSNR1: 33.0761 - SSIM1: 0.9083 - val_loss: 5.2154e-04 - val_PSNR1: 33.2082 - val_SSIM1: 0.9099 - 101s/epoch - 421ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00052
# 241/241 - 101s - loss: 5.4559e-04 - PSNR1: 33.0006 - SSIM1: 0.9086 - val_loss: 5.6710e-04 - val_PSNR1: 32.7912 - val_SSIM1: 0.9102 - 101s/epoch - 418ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00052
# 241/241 - 101s - loss: 5.3501e-04 - PSNR1: 33.0948 - SSIM1: 0.9095 - val_loss: 5.3056e-04 - val_PSNR1: 33.1223 - val_SSIM1: 0.9104 - 101s/epoch - 419ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.00052
# 241/241 - 101s - loss: 5.4504e-04 - PSNR1: 33.0070 - SSIM1: 0.9097 - val_loss: 5.6069e-04 - val_PSNR1: 32.8261 - val_SSIM1: 0.9096 - 101s/epoch - 421ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.00052
# 241/241 - 101s - loss: 5.3873e-04 - PSNR1: 33.0681 - SSIM1: 0.9104 - val_loss: 5.3402e-04 - val_PSNR1: 33.0876 - val_SSIM1: 0.9111 - 101s/epoch - 419ms/step
# Epoch 42/100
#
# Epoch 42: val_loss improved from 0.00052 to 0.00052, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.2333e-04 - PSNR1: 33.1890 - SSIM1: 0.9110 - val_loss: 5.2116e-04 - val_PSNR1: 33.2007 - val_SSIM1: 0.9125 - 101s/epoch - 419ms/step
# Epoch 43/100
#
# Epoch 43: val_loss improved from 0.00052 to 0.00050, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.2368e-04 - PSNR1: 33.1815 - SSIM1: 0.9116 - val_loss: 5.0352e-04 - val_PSNR1: 33.3717 - val_SSIM1: 0.9133 - 101s/epoch - 418ms/step
# Epoch 44/100
#
# Epoch 44: val_loss improved from 0.00050 to 0.00050, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.2769e-04 - PSNR1: 33.1539 - SSIM1: 0.9116 - val_loss: 5.0338e-04 - val_PSNR1: 33.3540 - val_SSIM1: 0.9132 - 101s/epoch - 420ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.00050
# 241/241 - 101s - loss: 5.3256e-04 - PSNR1: 33.1226 - SSIM1: 0.9120 - val_loss: 5.3783e-04 - val_PSNR1: 33.0326 - val_SSIM1: 0.9133 - 101s/epoch - 420ms/step
# Epoch 46/100
#
# Epoch 46: val_loss improved from 0.00050 to 0.00049, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.1051e-04 - PSNR1: 33.3035 - SSIM1: 0.9128 - val_loss: 4.9185e-04 - val_PSNR1: 33.4768 - val_SSIM1: 0.9142 - 101s/epoch - 420ms/step
# Epoch 47/100
#
# Epoch 47: val_loss improved from 0.00049 to 0.00049, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.0166e-04 - PSNR1: 33.3848 - SSIM1: 0.9135 - val_loss: 4.8747e-04 - val_PSNR1: 33.5045 - val_SSIM1: 0.9144 - 101s/epoch - 420ms/step
# Epoch 48/100
#
# Epoch 48: val_loss improved from 0.00049 to 0.00049, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.2095e-04 - PSNR1: 33.2048 - SSIM1: 0.9135 - val_loss: 4.8547e-04 - val_PSNR1: 33.5236 - val_SSIM1: 0.9148 - 101s/epoch - 420ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.00049
# 241/241 - 101s - loss: 5.0103e-04 - PSNR1: 33.3897 - SSIM1: 0.9142 - val_loss: 5.0692e-04 - val_PSNR1: 33.3259 - val_SSIM1: 0.9147 - 101s/epoch - 420ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.00049
# 241/241 - 101s - loss: 5.0380e-04 - PSNR1: 33.3621 - SSIM1: 0.9144 - val_loss: 4.9110e-04 - val_PSNR1: 33.4769 - val_SSIM1: 0.9157 - 101s/epoch - 420ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.00049
# 241/241 - 101s - loss: 4.9704e-04 - PSNR1: 33.4203 - SSIM1: 0.9148 - val_loss: 4.8622e-04 - val_PSNR1: 33.5076 - val_SSIM1: 0.9159 - 101s/epoch - 420ms/step
# Epoch 52/100
#
# Epoch 52: val_loss improved from 0.00049 to 0.00048, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 5.1281e-04 - PSNR1: 33.2942 - SSIM1: 0.9147 - val_loss: 4.8349e-04 - val_PSNR1: 33.5478 - val_SSIM1: 0.9164 - 101s/epoch - 420ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.00048
# 241/241 - 101s - loss: 4.8616e-04 - PSNR1: 33.5230 - SSIM1: 0.9157 - val_loss: 4.8521e-04 - val_PSNR1: 33.5243 - val_SSIM1: 0.9167 - 101s/epoch - 419ms/step
# Epoch 54/100
#
# Epoch 54: val_loss improved from 0.00048 to 0.00048, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 102s - loss: 4.9131e-04 - PSNR1: 33.4661 - SSIM1: 0.9157 - val_loss: 4.8314e-04 - val_PSNR1: 33.5484 - val_SSIM1: 0.9165 - 102s/epoch - 422ms/step
# Epoch 55/100
#
# Epoch 55: val_loss improved from 0.00048 to 0.00047, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.9165e-04 - PSNR1: 33.4691 - SSIM1: 0.9160 - val_loss: 4.7161e-04 - val_PSNR1: 33.6628 - val_SSIM1: 0.9173 - 101s/epoch - 420ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.00047
# 241/241 - 101s - loss: 5.0483e-04 - PSNR1: 33.3841 - SSIM1: 0.9160 - val_loss: 4.7223e-04 - val_PSNR1: 33.6637 - val_SSIM1: 0.9177 - 101s/epoch - 420ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.00047
# 241/241 - 101s - loss: 4.8555e-04 - PSNR1: 33.5216 - SSIM1: 0.9166 - val_loss: 4.7286e-04 - val_PSNR1: 33.6347 - val_SSIM1: 0.9172 - 101s/epoch - 420ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.00047
# 241/241 - 101s - loss: 4.7979e-04 - PSNR1: 33.5761 - SSIM1: 0.9169 - val_loss: 4.9632e-04 - val_PSNR1: 33.4098 - val_SSIM1: 0.9178 - 101s/epoch - 419ms/step
# Epoch 59/100
#
# Epoch 59: val_loss improved from 0.00047 to 0.00047, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.7752e-04 - PSNR1: 33.5979 - SSIM1: 0.9172 - val_loss: 4.6564e-04 - val_PSNR1: 33.7362 - val_SSIM1: 0.9183 - 101s/epoch - 419ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.00047
# 241/241 - 101s - loss: 4.8004e-04 - PSNR1: 33.5738 - SSIM1: 0.9175 - val_loss: 4.8683e-04 - val_PSNR1: 33.5055 - val_SSIM1: 0.9165 - 101s/epoch - 420ms/step
# Epoch 61/100
#
# Epoch 61: val_loss improved from 0.00047 to 0.00046, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.7388e-04 - PSNR1: 33.6332 - SSIM1: 0.9178 - val_loss: 4.5931e-04 - val_PSNR1: 33.7726 - val_SSIM1: 0.9189 - 101s/epoch - 419ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.00046
# 241/241 - 101s - loss: 4.8426e-04 - PSNR1: 33.5281 - SSIM1: 0.9175 - val_loss: 4.6471e-04 - val_PSNR1: 33.7185 - val_SSIM1: 0.9186 - 101s/epoch - 420ms/step
# Epoch 63/100
#
# Epoch 63: val_loss improved from 0.00046 to 0.00046, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.7687e-04 - PSNR1: 33.5967 - SSIM1: 0.9181 - val_loss: 4.5506e-04 - val_PSNR1: 33.8204 - val_SSIM1: 0.9196 - 101s/epoch - 420ms/step
# Epoch 64/100
#
# Epoch 64: val_loss improved from 0.00046 to 0.00045, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.6628e-04 - PSNR1: 33.7062 - SSIM1: 0.9186 - val_loss: 4.5205e-04 - val_PSNR1: 33.8589 - val_SSIM1: 0.9194 - 101s/epoch - 420ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.7135e-04 - PSNR1: 33.6550 - SSIM1: 0.9186 - val_loss: 5.2310e-04 - val_PSNR1: 33.1034 - val_SSIM1: 0.9200 - 101s/epoch - 420ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.6228e-04 - PSNR1: 33.7399 - SSIM1: 0.9190 - val_loss: 5.3078e-04 - val_PSNR1: 33.0222 - val_SSIM1: 0.9187 - 101s/epoch - 420ms/step
# Epoch 67/100
#
# Epoch 67: val_loss improved from 0.00045 to 0.00045, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.7534e-04 - PSNR1: 33.6132 - SSIM1: 0.9188 - val_loss: 4.4681e-04 - val_PSNR1: 33.8977 - val_SSIM1: 0.9203 - 101s/epoch - 420ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.6319e-04 - PSNR1: 33.7350 - SSIM1: 0.9192 - val_loss: 4.5001e-04 - val_PSNR1: 33.8749 - val_SSIM1: 0.9203 - 101s/epoch - 420ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.6040e-04 - PSNR1: 33.7567 - SSIM1: 0.9195 - val_loss: 4.4828e-04 - val_PSNR1: 33.8845 - val_SSIM1: 0.9207 - 101s/epoch - 420ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.6190e-04 - PSNR1: 33.7413 - SSIM1: 0.9197 - val_loss: 4.5172e-04 - val_PSNR1: 33.8442 - val_SSIM1: 0.9201 - 101s/epoch - 419ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.5372e-04 - PSNR1: 33.8260 - SSIM1: 0.9201 - val_loss: 4.5118e-04 - val_PSNR1: 33.8502 - val_SSIM1: 0.9207 - 101s/epoch - 419ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.6881e-04 - PSNR1: 33.6762 - SSIM1: 0.9198 - val_loss: 4.8892e-04 - val_PSNR1: 33.4359 - val_SSIM1: 0.9202 - 101s/epoch - 421ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.00045
# 241/241 - 101s - loss: 4.5907e-04 - PSNR1: 33.7685 - SSIM1: 0.9200 - val_loss: 4.6181e-04 - val_PSNR1: 33.7077 - val_SSIM1: 0.9211 - 101s/epoch - 420ms/step
# Epoch 74/100
#
# Epoch 74: val_loss improved from 0.00045 to 0.00044, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.5092e-04 - PSNR1: 33.8513 - SSIM1: 0.9206 - val_loss: 4.3628e-04 - val_PSNR1: 34.0186 - val_SSIM1: 0.9215 - 101s/epoch - 420ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.00044
# 241/241 - 101s - loss: 4.6244e-04 - PSNR1: 33.7476 - SSIM1: 0.9202 - val_loss: 4.7013e-04 - val_PSNR1: 33.6362 - val_SSIM1: 0.9210 - 101s/epoch - 419ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.00044
# 241/241 - 101s - loss: 4.6586e-04 - PSNR1: 33.6918 - SSIM1: 0.9202 - val_loss: 4.5581e-04 - val_PSNR1: 33.8055 - val_SSIM1: 0.9216 - 101s/epoch - 420ms/step
# Epoch 77/100
#
# Epoch 77: val_loss improved from 0.00044 to 0.00044, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.5610e-04 - PSNR1: 33.7886 - SSIM1: 0.9207 - val_loss: 4.3512e-04 - val_PSNR1: 34.0278 - val_SSIM1: 0.9218 - 101s/epoch - 420ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.00044
# 241/241 - 101s - loss: 4.4131e-04 - PSNR1: 33.9518 - SSIM1: 0.9214 - val_loss: 4.4365e-04 - val_PSNR1: 33.9152 - val_SSIM1: 0.9211 - 101s/epoch - 420ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.00044
# 241/241 - 101s - loss: 4.4544e-04 - PSNR1: 33.9026 - SSIM1: 0.9215 - val_loss: 4.7706e-04 - val_PSNR1: 33.5634 - val_SSIM1: 0.9220 - 101s/epoch - 419ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.00044
# 241/241 - 101s - loss: 4.6740e-04 - PSNR1: 33.7029 - SSIM1: 0.9206 - val_loss: 4.3963e-04 - val_PSNR1: 33.9651 - val_SSIM1: 0.9214 - 101s/epoch - 420ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.00044
# 241/241 - 101s - loss: 4.4483e-04 - PSNR1: 33.9052 - SSIM1: 0.9214 - val_loss: 4.3585e-04 - val_PSNR1: 34.0005 - val_SSIM1: 0.9222 - 101s/epoch - 421ms/step
# Epoch 82/100
#
# Epoch 82: val_loss improved from 0.00044 to 0.00043, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.3489e-04 - PSNR1: 34.0181 - SSIM1: 0.9221 - val_loss: 4.3053e-04 - val_PSNR1: 34.0733 - val_SSIM1: 0.9216 - 101s/epoch - 420ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.4100e-04 - PSNR1: 33.9490 - SSIM1: 0.9219 - val_loss: 4.6688e-04 - val_PSNR1: 33.6645 - val_SSIM1: 0.9229 - 101s/epoch - 419ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.00043
# 241/241 - 102s - loss: 4.4442e-04 - PSNR1: 33.9067 - SSIM1: 0.9220 - val_loss: 4.3560e-04 - val_PSNR1: 34.0111 - val_SSIM1: 0.9227 - 102s/epoch - 421ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.4950e-04 - PSNR1: 33.8690 - SSIM1: 0.9220 - val_loss: 4.7509e-04 - val_PSNR1: 33.5555 - val_SSIM1: 0.9213 - 101s/epoch - 419ms/step
# Epoch 86/100
#
# Epoch 86: val_loss improved from 0.00043 to 0.00043, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.3327e-04 - PSNR1: 34.0307 - SSIM1: 0.9224 - val_loss: 4.2834e-04 - val_PSNR1: 34.0818 - val_SSIM1: 0.9232 - 101s/epoch - 420ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.3483e-04 - PSNR1: 34.0110 - SSIM1: 0.9227 - val_loss: 4.3012e-04 - val_PSNR1: 34.0744 - val_SSIM1: 0.9235 - 101s/epoch - 419ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.4051e-04 - PSNR1: 33.9489 - SSIM1: 0.9223 - val_loss: 4.5494e-04 - val_PSNR1: 33.8135 - val_SSIM1: 0.9212 - 101s/epoch - 420ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.3239e-04 - PSNR1: 34.0360 - SSIM1: 0.9229 - val_loss: 4.5304e-04 - val_PSNR1: 33.7847 - val_SSIM1: 0.9234 - 101s/epoch - 420ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.3901e-04 - PSNR1: 33.9603 - SSIM1: 0.9227 - val_loss: 4.7474e-04 - val_PSNR1: 33.6005 - val_SSIM1: 0.9225 - 101s/epoch - 419ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.3401e-04 - PSNR1: 34.0213 - SSIM1: 0.9229 - val_loss: 4.2930e-04 - val_PSNR1: 34.0625 - val_SSIM1: 0.9225 - 101s/epoch - 420ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.3033e-04 - PSNR1: 34.0574 - SSIM1: 0.9231 - val_loss: 4.3694e-04 - val_PSNR1: 33.9734 - val_SSIM1: 0.9234 - 101s/epoch - 419ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.00043
# 241/241 - 101s - loss: 4.3384e-04 - PSNR1: 34.0160 - SSIM1: 0.9232 - val_loss: 4.3840e-04 - val_PSNR1: 33.9618 - val_SSIM1: 0.9229 - 101s/epoch - 419ms/step
# Epoch 94/100
#
# Epoch 94: val_loss improved from 0.00043 to 0.00042, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.3586e-04 - PSNR1: 33.9959 - SSIM1: 0.9231 - val_loss: 4.2453e-04 - val_PSNR1: 34.1289 - val_SSIM1: 0.9232 - 101s/epoch - 420ms/step
# Epoch 95/100
#
# Epoch 95: val_loss improved from 0.00042 to 0.00042, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.2770e-04 - PSNR1: 34.0794 - SSIM1: 0.9234 - val_loss: 4.2062e-04 - val_PSNR1: 34.1614 - val_SSIM1: 0.9239 - 101s/epoch - 420ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.00042
# 241/241 - 101s - loss: 4.2895e-04 - PSNR1: 34.0679 - SSIM1: 0.9236 - val_loss: 4.2192e-04 - val_PSNR1: 34.1539 - val_SSIM1: 0.9244 - 101s/epoch - 420ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.00042
# 241/241 - 101s - loss: 4.4554e-04 - PSNR1: 33.9271 - SSIM1: 0.9227 - val_loss: 4.3058e-04 - val_PSNR1: 34.0647 - val_SSIM1: 0.9238 - 101s/epoch - 420ms/step
# Epoch 98/100
#
# Epoch 98: val_loss improved from 0.00042 to 0.00041, saving model to ./checkpoint\De_CAE_poisson_42_추가.ckpt
# 241/241 - 101s - loss: 4.2030e-04 - PSNR1: 34.1629 - SSIM1: 0.9239 - val_loss: 4.1433e-04 - val_PSNR1: 34.2447 - val_SSIM1: 0.9245 - 101s/epoch - 419ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.00041
# 241/241 - 101s - loss: 4.3236e-04 - PSNR1: 34.0391 - SSIM1: 0.9235 - val_loss: 4.1957e-04 - val_PSNR1: 34.1716 - val_SSIM1: 0.9249 - 101s/epoch - 420ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.00041
# 241/241 - 101s - loss: 4.2146e-04 - PSNR1: 34.1484 - SSIM1: 0.9240 - val_loss: 4.2266e-04 - val_PSNR1: 34.1368 - val_SSIM1: 0.9232 - 101s/epoch - 419ms/step

# %%
import pandas as pd

# %%
hist_df = pd.DataFrame(autoencodersp_train.history) 
hist_df
# Out:
#         loss      PSNR1     SSIM1  val_loss  val_PSNR1  val_SSIM1
# 0   0.008421  24.280918  0.755011  0.001652  28.335907   0.821591
# 1   0.001493  28.741089  0.828097  0.001541  28.492109   0.834320
# 2   0.001303  29.278624  0.838598  0.001188  29.697109   0.843015
# 3   0.001176  29.724092  0.844988  0.001123  29.927670   0.848312
# 4   0.001139  29.847414  0.849256  0.001204  29.485405   0.853230
# ..       ...        ...       ...       ...        ...        ...
# 95  0.000429  34.067883  0.923573  0.000422  34.153912   0.924447
# 96  0.000446  33.927052  0.922721  0.000431  34.064735   0.923751
# 97  0.000420  34.162945  0.923902  0.000414  34.244656   0.924524
# 98  0.000432  34.039139  0.923457  0.000420  34.171650   0.924914
# 99  0.000421  34.148392  0.923980  0.000423  34.136841   0.923194
#
# [100 rows x 6 columns]

# %%
hist_df.to_csv('./csv/de_cdae_poisson_42_추가.csv')

# %%
autoencoder_sp.load_weights(filename)

# %%
start = time.time()
cae_x_test_sp_noisy = autoencoder_sp.predict(x_test_cae_sp_noisy,batch_size=batch_size)
print(cae_x_test_sp_noisy.shape)
end = time.time()
Caetime= end - start
print("CPU 시간 : "+str(Caetime))
cae_x_test_sp_noisy = tf.reshape(cae_x_test_sp_noisy,[724, 128, 128])
# Out:
# 81/81 [==============================] - 24s 296ms/step
# (724, 128, 128, 1)
# CPU 시간 : 24.009983777999878

# %%
ax = plt.subplot()
plt.imshow(cae_x_test_sp_noisy[21], cmap=plt.cm.gray)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title("(Improved CAEfilter Img)", position=(0.5,-0.12),fontsize = "xx-large")
plt.show()

# %%
# 5x5 서브플롯 생성
fig, axs = plt.subplots(5, 5, figsize=(20, 20))

# 각 서브플롯에 이미지 출력
for i, ax in enumerate(axs.flat):
    ax.imshow(cae_x_test_sp_noisy[i], cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %%
# data = pd.read_csv("./csv/de_cdae_gauss_batch9_10회_사용X_51.csv")
# data

# %%
# loss = data['loss'].tolist()
# val_loss = data['val_loss'].tolist()

# %%
import matplotlib

# %%
cae_loss = autoencodersp_train.history['loss']
cae_val_loss = autoencodersp_train.history['val_loss']
epochs = range(100)
plt.figure()
plt.plot(epochs, cae_loss, 'b', label="train")

plt.plot(epochs, cae_val_loss, 'g', label="validation")
plt.xlabel("epoch",fontsize=15)
plt.ylabel("loss",fontsize=18)
plt.rc('xtick', labelsize=13)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=12)  # y축 눈금 폰트 크기
plt.legend()
plt.legend(fontsize=15)
plt.show()

# %%
cae_loss = autoencodersp_train.history['PSNR1']
cae_val_loss = autoencodersp_train.history['val_PSNR1']
epochs = range(100)
plt.figure()
plt.plot(epochs, cae_loss, 'b', label="train")#
plt.plot(epochs, cae_val_loss, 'r', label="validation")
plt.xlabel("epoch")
plt.ylabel("PSNR")
plt.legend()
plt.show()

# %%
cae_loss = autoencodersp_train.history['SSIM1']
cae_val_loss = autoencodersp_train.history['val_SSIM1']
epochs = range(100)
plt.figure()
plt.plot(epochs, cae_loss, 'b', label="train")
plt.plot(epochs, cae_val_loss, 'r', label="validation")
plt.xlabel("epoch")
plt.ylabel("SSIM")
plt.legend()
plt.show()

# %%
from skimage.metrics import structural_similarity as ssim

# %%
cae_x_test_sp_noisy = cae_x_test_sp_noisy.numpy()

# %%
psnr_mean = []
mae_mean = []
psnr_median = []
mae_median = []
# psnr_nlmeans = []
# mae_nlmeans = []
# psnr_bilateral = []
# mae_bilateral = []
# psnr_wavelet = []
# mae_wavelet = []

psnr_cae = []
mae_cae = []



ssim_mean=[]
ssim_median=[]
# ssim_nlmeans=[]
# ssim_bilateral=[]
# ssim_wavelet=[]
ssim_cae=[]

for i in range(len(x_test_sp_noisy)):
    mae_mean.append(MAE(mean_x_test_sp_noisy[i],x_test[i]))
    mae_median.append(MAE(median_x_test_sp_noisy[i],x_test[i]))
#     mae_nlmeans.append(MAE(nlmeans_x_test_sp_noisy[i],x_test[i]))
#     mae_bilateral.append(MAE(bilateral_x_test_sp_noisy[i],x_test[i]))  
    mae_cae.append(MAE(cae_x_test_sp_noisy[i],x_test[i]))
    
    psnr_mean.append(PSNR(mean_x_test_sp_noisy[i],x_test[i]))
    psnr_median.append(PSNR(median_x_test_sp_noisy[i],x_test[i]))
#     psnr_nlmeans.append(PSNR(nlmeans_x_test_sp_noisy[i],x_test[i]))
#     psnr_bilateral.append(PSNR(bilateral_x_test_sp_noisy[i],x_test[i]))
    
    psnr_cae.append(PSNR(cae_x_test_sp_noisy[i],x_test[i]))
    
    ssim_mean.append(ssim(x_test[i], mean_x_test_sp_noisy[i]))
    ssim_median.append(ssim(x_test[i], median_x_test_sp_noisy[i]))
#     ssim_nlmeans.append(ssim(x_test[i], nlmeans_x_test_sp_noisy[i]))
#     ssim_bilateral.append(ssim(x_test[i], bilateral_x_test_sp_noisy[i]))
    
    ssim_cae.append(ssim(x_test[i], cae_x_test_sp_noisy[i]))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\skimage\_shared\utils.py:348: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   return func(*args, **kwargs)

# %%
print("About Poisson Noisy")
print("Mean Filter : MAE = " +  str(np.mean(mae_mean)) + " & PSNR = " + str(np.mean(psnr_mean))+" & SSIM = "+str(np.mean(ssim_mean)))
print("Median Filter : MAE = " +  str(np.mean(mae_median)) + " & PSNR = " + str(np.mean(psnr_median))+" & SSIM = "+str(np.mean(ssim_median)))
#print("Bilateral Filter : MAE = " +  str(np.mean(mae_bilateral)) + " & PSNR = " + str(np.mean(psnr_bilateral))+" & SSIM = "+str(np.mean(ssim_bilateral)))
#print("NL Means Filter : MAE = " +  str(np.mean(mae_nlmeans)) + " & PSNR = " + str(np.mean(psnr_nlmeans))+" & SSIM = "+str(np.mean(ssim_nlmeans)))
#print("Wavelet Filter : MAE = " +  str(np.mean(mae_wavelet)) + " & PSNR = " + str(np.mean(psnr_wavelet))+" & SSIM = "+str(np.mean(ssim_wavelet)))
print("De_CAE Filter : MAE = " +  str(np.mean(mae_cae)) + " & PSNR = " + str(np.mean(psnr_cae))+" & SSIM = "+str(np.mean(ssim_cae)))
# Out:
# About Poisson Noisy
# Mean Filter : MAE = 0.09349531368808504 & PSNR = 19.896051503102004 & SSIM = 0.8329750546148834
# Median Filter : MAE = 0.08341873383986118 & PSNR = 20.350983190342028 & SSIM = 0.7538754618360591
# De_CAE Filter : MAE = 0.013095894592544458 & PSNR = 34.10683014742511 & SSIM = 0.9624252224828478
